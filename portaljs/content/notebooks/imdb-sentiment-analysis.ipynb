# %% [markdown]
# # IMDB Sentiment Analysis - Data Explorer
#
#
#
# **Task:** Text Classification / Sentiment Analysis
#
#
#
# Analyze movie reviews and predict sentiment using the IMDB dataset.
#
#
#
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/gg-daddy/ckan-docker/blob/portjs-inte/portaljs/content/notebooks/imdb-sentiment-analysis.ipynb)

# %% [markdown]
# ## 1. Setup
#
#
#
# Install required packages.

# %%
# !pip install datasets pandas matplotlib -q

# %% [markdown]
# ## 2. Load Dataset
#
#
#
# Load the dataset from Hugging Face: `stanfordnlp/imdb`

# %%
from datasets import load_dataset

import pandas as pd



dataset = load_dataset("stanfordnlp/imdb")



# Display dataset info

print(dataset)

print(f"\nTrain samples: {len(dataset['train'])}")

# %% [markdown]
# ## 3. Explore Data
#
#
#
# View sample data from the dataset.

# %%
# View sample reviews
print("Sample positive review:")
print(dataset["train"][0]["text"][:500])
print(f"Label: {dataset["train"][0]["label"]} (0=negative, 1=positive)")

# Analyze label distribution
import collections
labels = [ex["label"] for ex in dataset["train"]]
print(f"\nLabel distribution: {dict(collections.Counter(labels))}")

# %% [markdown]
# ## 4. Visualize Data
#
#
#
# Create visualizations to understand the data distribution.

# %%
# Visualize review length distribution
import matplotlib.pyplot as plt

lengths = [len(ex["text"].split()) for ex in dataset["train"][:5000]]
plt.figure(figsize=(10, 5))
plt.hist(lengths, bins=50, edgecolor='black')
plt.xlabel('Number of Words')
plt.ylabel('Frequency')
plt.title('Distribution of Review Lengths')
plt.axvline(x=sum(lengths)/len(lengths), color='red', linestyle='--', label=f'Mean: {sum(lengths)/len(lengths):.0f}')
plt.legend()
plt.show()

# %% [markdown]
# ## 5. Convert to Pandas
#
#
#
# For further analysis, convert to a pandas DataFrame.

# %%
# Convert to pandas DataFrame

df = dataset['train'].to_pandas()



print(f"DataFrame shape: {df.shape}")

print(f"\nColumns: {list(df.columns)}")

print(f"\nData types:")

print(df.dtypes)



df.head()

# %% [markdown]
# ## Next Steps
#
#
#
# - Train a model using this dataset
#
# - Fine-tune a pretrained model
#
# - Export processed data
#
# - Combine with other datasets
#
#
#
# For more information, visit the [Hugging Face Dataset Page](https://huggingface.co/datasets/stanfordnlp/imdb)
