# %% [markdown]
# # Dolly Instruction Following - Data Explorer
#
#
#
# **Task:** Instruction Following
#
#
#
# Explore human-generated instruction-response pairs from Databricks.
#
#
#
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/gg-daddy/ckan-docker/blob/portjs-inte/portaljs/content/notebooks/dolly-instruction-following.ipynb)

# %% [markdown]
# ## 1. Setup
#
#
#
# Install required packages.

# %%
# !pip install datasets pandas matplotlib -q

# %% [markdown]
# ## 2. Load Dataset
#
#
#
# Load the dataset from Hugging Face: `databricks/databricks-dolly-15k`

# %%
from datasets import load_dataset

import pandas as pd



dataset = load_dataset("databricks/databricks-dolly-15k")



# Display dataset info

print(dataset)

print(f"\nTrain samples: {len(dataset['train'])}")

# %% [markdown]
# ## 3. Explore Data
#
#
#
# View sample data from the dataset.

# %%
# View a sample instruction
sample = dataset["train"][0]
print(f"Category: {sample['category']}")
print(f"\nInstruction: {sample['instruction']}")
if sample.get("context"):
    print(f"\nContext: {sample['context'][:200]}...")
print(f"\nResponse: {sample['response'][:500]}...")

# %% [markdown]
# ## 4. Visualize Data
#
#
#
# Create visualizations to understand the data distribution.

# %%
# Analyze instruction categories
import matplotlib.pyplot as plt
import collections

categories = [ex["category"] for ex in dataset["train"]]
cat_counts = collections.Counter(categories)

plt.figure(figsize=(12, 5))
plt.barh(list(cat_counts.keys()), list(cat_counts.values()), color='steelblue')
plt.xlabel('Count')
plt.title('Distribution of Instruction Categories')
for i, v in enumerate(cat_counts.values()):
    plt.text(v + 10, i, str(v), va='center')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 5. Convert to Pandas
#
#
#
# For further analysis, convert to a pandas DataFrame.

# %%
# Convert to pandas DataFrame

df = dataset['train'].to_pandas()



print(f"DataFrame shape: {df.shape}")

print(f"\nColumns: {list(df.columns)}")

print(f"\nData types:")

print(df.dtypes)



df.head()

# %% [markdown]
# ## Next Steps
#
#
#
# - Train a model using this dataset
#
# - Fine-tune a pretrained model
#
# - Export processed data
#
# - Combine with other datasets
#
#
#
# For more information, visit the [Hugging Face Dataset Page](https://huggingface.co/datasets/databricks/databricks-dolly-15k)
