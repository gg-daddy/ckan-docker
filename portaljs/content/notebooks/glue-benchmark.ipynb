# %% [markdown]
# # GLUE Benchmark (SST-2) - Data Explorer
#
#
#
# **Task:** Natural Language Understanding
#
#
#
# Explore the GLUE benchmark SST-2 sentiment classification task.
#
#
#
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/gg-daddy/ckan-docker/blob/portjs-inte/portaljs/content/notebooks/glue-benchmark.ipynb)

# %% [markdown]
# ## 1. Setup
#
#
#
# Install required packages.

# %%
# !pip install datasets pandas matplotlib -q

# %% [markdown]
# ## 2. Load Dataset
#
#
#
# Load the dataset from Hugging Face: `nyu-mll/glue`

# %%
from datasets import load_dataset

import pandas as pd



dataset = load_dataset("nyu-mll/glue", "sst2")



# Display dataset info

print(dataset)

print(f"\nTrain samples: {len(dataset['train'])}")

# %% [markdown]
# ## 3. Explore Data
#
#
#
# View sample data from the dataset.

# %%
# View sample sentences
for i in range(5):
    sample = dataset["train"][i]
    sentiment = "Positive" if sample["label"] == 1 else "Negative"
    print(f"{sentiment}: {sample['sentence']}")

# %% [markdown]
# ## 4. Visualize Data
#
#
#
# Create visualizations to understand the data distribution.

# %%
# Label distribution
import matplotlib.pyplot as plt
import collections

labels = [ex["label"] for ex in dataset["train"]]
label_counts = collections.Counter(labels)

plt.figure(figsize=(8, 5))
plt.bar(['Negative (0)', 'Positive (1)'], 
        [label_counts[0], label_counts[1]], 
        color=['salmon', 'lightgreen'])
plt.ylabel('Count')
plt.title('SST-2 Sentiment Distribution')
for i, v in enumerate([label_counts[0], label_counts[1]]):
    plt.text(i, v + 100, str(v), ha='center')
plt.show()

# %% [markdown]
# ## 5. Convert to Pandas
#
#
#
# For further analysis, convert to a pandas DataFrame.

# %%
# Convert to pandas DataFrame

df = dataset['train'].to_pandas()



print(f"DataFrame shape: {df.shape}")

print(f"\nColumns: {list(df.columns)}")

print(f"\nData types:")

print(df.dtypes)



df.head()

# %% [markdown]
# ## Next Steps
#
#
#
# - Train a model using this dataset
#
# - Fine-tune a pretrained model
#
# - Export processed data
#
# - Combine with other datasets
#
#
#
# For more information, visit the [Hugging Face Dataset Page](https://huggingface.co/datasets/nyu-mll/glue)
