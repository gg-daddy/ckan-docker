# %% [markdown]
# # CNN/DailyMail Summarization - Data Explorer
#
#
#
# **Task:** Text Summarization
#
#
#
# Analyze news articles and their summaries from CNN and DailyMail.
#
#
#
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/gg-daddy/ckan-docker/blob/portjs-inte/portaljs/content/notebooks/cnn-dailymail-summarization.ipynb)

# %% [markdown]
# ## 1. Setup
#
#
#
# Install required packages.

# %%
# !pip install datasets pandas matplotlib -q

# %% [markdown]
# ## 2. Load Dataset
#
#
#
# Load the dataset from Hugging Face: `abisee/cnn_dailymail`

# %%
from datasets import load_dataset

import pandas as pd



dataset = load_dataset("abisee/cnn_dailymail", "3.0.0")



# Display dataset info

print(dataset)

print(f"\nTrain samples: {len(dataset['train'])}")

# %% [markdown]
# ## 3. Explore Data
#
#
#
# View sample data from the dataset.

# %%
# View a sample article and its highlights
sample = dataset["train"][0]
print("Article (first 500 chars):")
print(sample["article"][:500], "...")
print(f"\nHighlights/Summary:")
print(sample["highlights"])

# %% [markdown]
# ## 4. Visualize Data
#
#
#
# Create visualizations to understand the data distribution.

# %%
# Compare article vs summary lengths
import matplotlib.pyplot as plt

article_lens = [len(ex["article"].split()) for ex in dataset["train"][:2000]]
summary_lens = [len(ex["highlights"].split()) for ex in dataset["train"][:2000]]

plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.hist(article_lens, bins=50, edgecolor='black', alpha=0.7)
plt.xlabel('Words')
plt.title('Article Length Distribution')

plt.subplot(1, 2, 2)
plt.hist(summary_lens, bins=50, edgecolor='black', alpha=0.7, color='orange')
plt.xlabel('Words')
plt.title('Summary Length Distribution')
plt.tight_layout()
plt.show()

print(f"Average compression ratio: {sum(article_lens)/sum(summary_lens):.1f}x")

# %% [markdown]
# ## 5. Convert to Pandas
#
#
#
# For further analysis, convert to a pandas DataFrame.

# %%
# Convert to pandas DataFrame

df = dataset['train'].to_pandas()



print(f"DataFrame shape: {df.shape}")

print(f"\nColumns: {list(df.columns)}")

print(f"\nData types:")

print(df.dtypes)



df.head()

# %% [markdown]
# ## Next Steps
#
#
#
# - Train a model using this dataset
#
# - Fine-tune a pretrained model
#
# - Export processed data
#
# - Combine with other datasets
#
#
#
# For more information, visit the [Hugging Face Dataset Page](https://huggingface.co/datasets/abisee/cnn_dailymail)
